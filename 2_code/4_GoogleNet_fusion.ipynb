# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import Dataset,DataLoader,TensorDataset
import torchvision
from torchvision.transforms import transforms
from torchvision import models
import matplotlib.pyplot as plt

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive 
from google.colab import auth 
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

import numpy as np
import pandas as pd

file_id = "1WZLFr195SGw2_UCzis-Djuov8c4HJPk1"
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('CXR_label.csv')

file_id = "1EixCdXLWw-tOh1ONlbIcQVTdw865c3sn"
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('CXR_image.npz')

file_id = "1RYZe6fiviC1ReJZb4H5B6nVb2-vUoEx7"
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('CT_label.csv')

file_id = "1WE6ntEDaXWAGMiphJqwG6uKGr-HxkV6Y"
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('CT_image.npz')

CXR_label = pd.read_csv('CXR_label.csv')
CXR_data = np.load(file='CXR_image.npz')
CXR_data_3d = CXR_data['arr']

CT_label = pd.read_csv('CT_label.csv')
CT_data = np.load(file='CT_image.npz')
CT_data_3d = CT_data['arr']

# %% [markdown]
# Split data set

# %%
CT_cov = CT_label[CT_label['finding']=='COVID-19']
CT_nor = CT_label[CT_label['finding']=='Normal']
CT_pne = CT_label[CT_label['finding']=='Pneumonia']

CXR_cov = CXR_label[CXR_label['finding']=='COVID-19']
CXR_nor = CXR_label[CXR_label['finding']=='Normal']
CXR_pne = CXR_label[CXR_label['finding']=='Pneumonia']

# %%
train_label = []
train_CT = []
train_CXR = []

for i in range(300):

  CTimg1 = CT_data_3d[CT_cov.index[i]]
  CXRimg1 = CXR_data_3d[CXR_cov.index[i]]

  train_label.append(2)
  train_CT.append(CTimg1)
  train_CXR.append(CXRimg1)

  CTimg2 = CT_data_3d[CT_nor.index[i]]
  CXRimg2 = CXR_data_3d[CXR_nor.index[i]]


  train_CT.append(CTimg2)
  train_CXR.append(CXRimg2)
  train_label.append(0)

  CTimg3 = CT_data_3d[CT_pne.index[i]]
  CXRimg3 = CXR_data_3d[CXR_pne.index[i]]

  train_CT.append(CTimg3)
  train_CXR.append(CXRimg3)
  train_label.append(1)

train_CXR = np.array(train_CXR)
train_CT = np.array(train_CT)
train_label = np.array(train_label)

# %%
test_CXR = []
test_CT = []
test_label = []


for i in range(300,325):

  CTimg1 = CT_data_3d[CT_cov.index[i]]
  CXRimg1 = CXR_data_3d[CXR_cov.index[i]]
  
  test_CT.append(CTimg1)
  test_CXR.append(CXRimg1)
  test_label.append(2)

  CTimg2 = CT_data_3d[CT_nor.index[i]]
  CXRimg2 = CXR_data_3d[CXR_nor.index[i]]

  test_CT.append(CTimg2)
  test_CXR.append(CXRimg2)
  test_label.append(0)

  CTimg3 = CT_data_3d[CT_pne.index[i]]
  CXRimg3 = CXR_data_3d[CXR_pne.index[i]]

  test_CT.append(CTimg3)
  test_CXR.append(CXRimg3)
  test_label.append(1)

test_CXR = np.array(test_CXR)
test_CT = np.array(test_CT)
test_label = np.array(test_label)

# %%
data_transforms = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# %%
#Extracting image features
def feature_extraction(data, model):
  inputs_ls = []
  outputs_ls = []
  for dat in data:
    inputs = data_transforms(dat)
    inputs_ls.append(inputs)
  del model.fc
  model.fc=lambda x:x

  for inputs in inputs_ls:
    inputs = torch.unsqueeze(inputs, dim=0)
    with torch.no_grad():
        outputs = model(inputs)
        outputs_ls.append(outputs)
        _, preds = torch.max(outputs, 1)
  return outputs_ls

# %%
def fuse_data(CT_data,CXR_data,model,w =0.5):
  # CT
  CT_features = feature_extraction(CT_data, model)

  # CXR
  CXR_features = feature_extraction(CXR_data, model)
  output = []

  for i, (x,y) in enumerate(zip(CXR_features,CT_features)):
        CXR_fuse = x[0]*w
        CT_fuse = y[0]*(1-w)
        _fused_data = CXR_fuse + CT_fuse
        output.append(_fused_data)

  out = torch.stack(output,0)

  return out

# %%
googlenet = models.googlenet(pretrained=True)
# Out:
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
#   0%|          | 0.00/49.7M [00:00<?, ?B/s]

# %%
fused_train_feature = fuse_data(train_CT,train_CXR,googlenet)
fused_test_feature = fuse_data(test_CT,test_CXR,googlenet)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:780: UserWarning: Note that order of the arguments: ceil_mode and return_indices will changeto match the args list in nn.MaxPool2d in a future release.
#   warnings.warn("Note that order of the arguments: ceil_mode and return_indices will change"

# %%
fused_train_feature
# Out:
# tensor([[0.4514, 0.4375, 0.4356,  ..., 0.5175, 0.2502, 0.2615],
#         [0.2084, 0.4562, 0.4596,  ..., 0.5124, 0.2532, 0.5005],
#         [0.4331, 0.4546, 0.4313,  ..., 0.5352, 0.2493, 0.5195],
#         ...,
#         [0.4522, 0.4470, 0.2390,  ..., 0.2697, 0.2423, 0.5060],
#         [0.4451, 0.4469, 0.4647,  ..., 0.5134, 0.2444, 0.4870],
#         [0.2194, 0.4432, 0.2220,  ..., 0.5216, 0.4807, 0.5285]])

# %%
y_train=torch.from_numpy(train_label)
y_test=torch.from_numpy(test_label)

x_train=fused_train_feature.float()
x_test=fused_test_feature.float()
y_train=y_train.long()
y_test=y_test.long()

train_dataset=TensorDataset(x_train,y_train)
test_dataset=TensorDataset(x_test,y_test)

# %%
#mini-batch
train_dataloader = DataLoader(dataset=train_dataset,batch_size=128, shuffle=True)
val_dataloader = DataLoader(dataset=test_dataset,batch_size=128, shuffle=True)

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
print('trian_device:{}'.format(device.type))
# Out:
# trian_device:cpu

# %%
model = models.googlenet(pretrained=True)

num_fc_in = model.fc.in_features

model.fc = nn.Linear(num_fc_in, 3)

FC = model.fc
model = FC.to(device)

loss_fc = nn.CrossEntropyLoss()

optimizer = optim.SGD(model.parameters(), lr=0.9, momentum=0.9)

exp_lr_scheduler = lr_scheduler.StepLR(optimizer=optimizer, step_size=20, gamma=0.9)  # step_size

# %%
for epoch in range(100):

    running_loss = 0.0
    
    for i, sample_batch in enumerate(train_dataloader):
        inputs = sample_batch[0]
        labels = sample_batch[1]

        model.train()

        # GPU/CPU
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        # foward
        outputs = model(inputs)
        mat = torch.zeros(len(labels), 3)
        y_trans = labels.view(-1, 1)
        labels = mat.scatter_(dim=1, index=y_trans, value=1)


        # loss
        loss = loss_fc(outputs, labels)

        loss.backward()

        optimizer.step()
        exp_lr_scheduler.step()

        running_loss += loss.item()
    
        if (i+1) % 3 == 0:
            correct = 0
            total = 0
            model.eval()
            for images_test, labels_test in train_dataloader:
                images_test = images_test.to(device)
                labels_test = labels_test.to(device)

                outputs_test = model(images_test)
                _, prediction = torch.max(outputs_test, 1)
                correct += (torch.sum((prediction == labels_test))).item()
               # print(prediction, labels_test, correct)
                total += labels_test.size(0)
            print('[{}, {}] running_loss = {:.5f} train accurcay = {:.5f}'.format(epoch + 1, i + 1, running_loss / 20,
                                                                        correct / total))
            running_loss = 0.0
    
print('training finish !')
# Out:
# [1, 3] running_loss = 3.06032 train accurcay = 0.33333
# [1, 6] running_loss = 10.57918 train accurcay = 0.33333
# [2, 3] running_loss = 15.25478 train accurcay = 0.33333
# [2, 6] running_loss = 17.24188 train accurcay = 0.33333
# [3, 3] running_loss = 36.11029 train accurcay = 0.33333
# [3, 6] running_loss = 43.89884 train accurcay = 0.33333
# [4, 3] running_loss = 26.58657 train accurcay = 0.33333
# [4, 6] running_loss = 20.40617 train accurcay = 0.33333
# [5, 3] running_loss = 29.91603 train accurcay = 0.33333
# [5, 6] running_loss = 14.42355 train accurcay = 0.33333
# [6, 3] running_loss = 21.17456 train accurcay = 0.51000
# [6, 6] running_loss = 11.29767 train accurcay = 0.33333
# [7, 3] running_loss = 13.66478 train accurcay = 0.33444
# [7, 6] running_loss = 16.81325 train accurcay = 0.33444
# [8, 3] running_loss = 6.99219 train accurcay = 0.33889
# [8, 6] running_loss = 5.14988 train accurcay = 0.43556
# [9, 3] running_loss = 5.77477 train accurcay = 0.33333
# [9, 6] running_loss = 8.98539 train accurcay = 0.33444
# [10, 3] running_loss = 10.78668 train accurcay = 0.33444
# [10, 6] running_loss = 8.43233 train accurcay = 0.33333
# [11, 3] running_loss = 8.78130 train accurcay = 0.33889
# [11, 6] running_loss = 13.67270 train accurcay = 0.35000
# [12, 3] running_loss = 14.27004 train accurcay = 0.33444
# [12, 6] running_loss = 12.13545 train accurcay = 0.53000
# [13, 3] running_loss = 15.35640 train accurcay = 0.33444
# [13, 6] running_loss = 12.32353 train accurcay = 0.51333
# [14, 3] running_loss = 6.88826 train accurcay = 0.33444
# [14, 6] running_loss = 7.26217 train accurcay = 0.34667
# [15, 3] running_loss = 12.64681 train accurcay = 0.33333
# [15, 6] running_loss = 11.95953 train accurcay = 0.33333
# [16, 3] running_loss = 9.58276 train accurcay = 0.33778
# [16, 6] running_loss = 12.15144 train accurcay = 0.35333
# [17, 3] running_loss = 4.22628 train accurcay = 0.55333
# [17, 6] running_loss = 2.66986 train accurcay = 0.44000
# [18, 3] running_loss = 1.58249 train accurcay = 0.40222
# [18, 6] running_loss = 2.28001 train accurcay = 0.61333
# [19, 3] running_loss = 1.51811 train accurcay = 0.59444
# [19, 6] running_loss = 1.48954 train accurcay = 0.65556
# [20, 3] running_loss = 1.79394 train accurcay = 0.53667
# [20, 6] running_loss = 1.25214 train accurcay = 0.50444
# [21, 3] running_loss = 0.95717 train accurcay = 0.55667
# [21, 6] running_loss = 0.85583 train accurcay = 0.58111
# [22, 3] running_loss = 1.38628 train accurcay = 0.63556
# [22, 6] running_loss = 1.17824 train accurcay = 0.65889
# [23, 3] running_loss = 2.31567 train accurcay = 0.54444
# [23, 6] running_loss = 2.00271 train accurcay = 0.40333
# [24, 3] running_loss = 1.05278 train accurcay = 0.70667
# [24, 6] running_loss = 0.76045 train accurcay = 0.68667
# [25, 3] running_loss = 0.80123 train accurcay = 0.59778
# [25, 6] running_loss = 0.83809 train accurcay = 0.56778
# [26, 3] running_loss = 0.36500 train accurcay = 0.74778
# [26, 6] running_loss = 0.32766 train accurcay = 0.73444
# [27, 3] running_loss = 0.38242 train accurcay = 0.75667
# [27, 6] running_loss = 0.30144 train accurcay = 0.79333
# [28, 3] running_loss = 0.40668 train accurcay = 0.75111
# [28, 6] running_loss = 0.40784 train accurcay = 0.68111
# [29, 3] running_loss = 0.61478 train accurcay = 0.68889
# [29, 6] running_loss = 0.54534 train accurcay = 0.79222
# [30, 3] running_loss = 0.94659 train accurcay = 0.58444
# [30, 6] running_loss = 0.80826 train accurcay = 0.56333
# [31, 3] running_loss = 0.99566 train accurcay = 0.60889
# [31, 6] running_loss = 0.84968 train accurcay = 0.64889
# [32, 3] running_loss = 1.28358 train accurcay = 0.75444
# [32, 6] running_loss = 0.92913 train accurcay = 0.67667
# [33, 3] running_loss = 0.91030 train accurcay = 0.65000
# [33, 6] running_loss = 0.88846 train accurcay = 0.70778
# [34, 3] running_loss = 1.38319 train accurcay = 0.47333
# [34, 6] running_loss = 0.90932 train accurcay = 0.64889
# [35, 3] running_loss = 0.55806 train accurcay = 0.74222
# [35, 6] running_loss = 0.34330 train accurcay = 0.79333
# [36, 3] running_loss = 1.26318 train accurcay = 0.74111
# [36, 6] running_loss = 0.70718 train accurcay = 0.76333
# [37, 3] running_loss = 0.41389 train accurcay = 0.77889
# [37, 6] running_loss = 0.27380 train accurcay = 0.77000
# [38, 3] running_loss = 0.48350 train accurcay = 0.80333
# [38, 6] running_loss = 0.43116 train accurcay = 0.82889
# [39, 3] running_loss = 0.34152 train accurcay = 0.80444
# [39, 6] running_loss = 0.31357 train accurcay = 0.84444
# [40, 3] running_loss = 1.32135 train accurcay = 0.75444
# [40, 6] running_loss = 0.92637 train accurcay = 0.61111
# [41, 3] running_loss = 1.30728 train accurcay = 0.79111
# [41, 6] running_loss = 0.54940 train accurcay = 0.63889
# [42, 3] running_loss = 0.28852 train accurcay = 0.67222
# [42, 6] running_loss = 0.38519 train accurcay = 0.78667
# [43, 3] running_loss = 0.41037 train accurcay = 0.81778
# [43, 6] running_loss = 0.28196 train accurcay = 0.86556
# [44, 3] running_loss = 0.29742 train accurcay = 0.85111
# [44, 6] running_loss = 0.24614 train accurcay = 0.78111
# [45, 3] running_loss = 0.40574 train accurcay = 0.73667
# [45, 6] running_loss = 0.23781 train accurcay = 0.75000
# [46, 3] running_loss = 0.16325 train accurcay = 0.83222
# [46, 6] running_loss = 0.18673 train accurcay = 0.85778
# [47, 3] running_loss = 0.15015 train accurcay = 0.85333
# [47, 6] running_loss = 0.12671 train accurcay = 0.87778
# [48, 3] running_loss = 0.22053 train accurcay = 0.85667
# [48, 6] running_loss = 0.11447 train accurcay = 0.87222
# [49, 3] running_loss = 0.12077 train accurcay = 0.86333
# [49, 6] running_loss = 0.09567 train accurcay = 0.84889
# [50, 3] running_loss = 0.10780 train accurcay = 0.86444
# [50, 6] running_loss = 0.09691 train accurcay = 0.87667
# [51, 3] running_loss = 0.17692 train accurcay = 0.86778
# [51, 6] running_loss = 0.10531 train accurcay = 0.84444
# [52, 3] running_loss = 0.12934 train accurcay = 0.83111
# [52, 6] running_loss = 0.15785 train accurcay = 0.86667
# [53, 3] running_loss = 0.12074 train accurcay = 0.89333
# [53, 6] running_loss = 0.08161 train accurcay = 0.89111
# [54, 3] running_loss = 0.09532 train accurcay = 0.87889
# [54, 6] running_loss = 0.09056 train accurcay = 0.89556
# [55, 3] running_loss = 0.07185 train accurcay = 0.88667
# [55, 6] running_loss = 0.09030 train accurcay = 0.87111
# [56, 3] running_loss = 0.06872 train accurcay = 0.89444
# [56, 6] running_loss = 0.08650 train accurcay = 0.90111
# [57, 3] running_loss = 0.10933 train accurcay = 0.87111
# [57, 6] running_loss = 0.05943 train accurcay = 0.89111
# [58, 3] running_loss = 0.07495 train accurcay = 0.89000
# [58, 6] running_loss = 0.05817 train accurcay = 0.88778
# [59, 3] running_loss = 0.12044 train accurcay = 0.85667
# [59, 6] running_loss = 0.08075 train accurcay = 0.87111
# [60, 3] running_loss = 0.09430 train accurcay = 0.89222
# [60, 6] running_loss = 0.08486 train accurcay = 0.87444
# [61, 3] running_loss = 0.09841 train accurcay = 0.87778
# [61, 6] running_loss = 0.07786 train accurcay = 0.89556
# [62, 3] running_loss = 0.09040 train accurcay = 0.89667
# [62, 6] running_loss = 0.07192 train accurcay = 0.87000
# [63, 3] running_loss = 0.07122 train accurcay = 0.89667
# [63, 6] running_loss = 0.08865 train accurcay = 0.89111
# [64, 3] running_loss = 0.08637 train accurcay = 0.88778
# [64, 6] running_loss = 0.04931 train accurcay = 0.90778
# [65, 3] running_loss = 0.05922 train accurcay = 0.91000
# [65, 6] running_loss = 0.06559 train accurcay = 0.88889
# [66, 3] running_loss = 0.06432 train accurcay = 0.88556
# [66, 6] running_loss = 0.07571 train accurcay = 0.90667
# [67, 3] running_loss = 0.09360 train accurcay = 0.87444
# [67, 6] running_loss = 0.06229 train accurcay = 0.91333
# [68, 3] running_loss = 0.08551 train accurcay = 0.90000
# [68, 6] running_loss = 0.06375 train accurcay = 0.89333
# [69, 3] running_loss = 0.06506 train accurcay = 0.90556
# [69, 6] running_loss = 0.06627 train accurcay = 0.91111
# [70, 3] running_loss = 0.06153 train accurcay = 0.89111
# [70, 6] running_loss = 0.06615 train accurcay = 0.91000
# [71, 3] running_loss = 0.08491 train accurcay = 0.90667
# [71, 6] running_loss = 0.03782 train accurcay = 0.91444
# [72, 3] running_loss = 0.06831 train accurcay = 0.89889
# [72, 6] running_loss = 0.05545 train accurcay = 0.91333
# [73, 3] running_loss = 0.06311 train accurcay = 0.91889
# [73, 6] running_loss = 0.03768 train accurcay = 0.92111
# [74, 3] running_loss = 0.09115 train accurcay = 0.86667
# [74, 6] running_loss = 0.06520 train accurcay = 0.90222
# [75, 3] running_loss = 0.06315 train accurcay = 0.90333
# [75, 6] running_loss = 0.06011 train accurcay = 0.92111
# [76, 3] running_loss = 0.05633 train accurcay = 0.92222
# [76, 6] running_loss = 0.04436 train accurcay = 0.92000
# [77, 3] running_loss = 0.04724 train accurcay = 0.91889
# [77, 6] running_loss = 0.04873 train accurcay = 0.93333
# [78, 3] running_loss = 0.05503 train accurcay = 0.92444
# [78, 6] running_loss = 0.03797 train accurcay = 0.92556
# [79, 3] running_loss = 0.03729 train accurcay = 0.92556
# [79, 6] running_loss = 0.04561 train accurcay = 0.92778
# [80, 3] running_loss = 0.04683 train accurcay = 0.93222
# [80, 6] running_loss = 0.02143 train accurcay = 0.92556
# [81, 3] running_loss = 0.05201 train accurcay = 0.89444
# [81, 6] running_loss = 0.06385 train accurcay = 0.92222
# [82, 3] running_loss = 0.04671 train accurcay = 0.91333
# [82, 6] running_loss = 0.03701 train accurcay = 0.91556
# [83, 3] running_loss = 0.04104 train accurcay = 0.93333
# [83, 6] running_loss = 0.04465 train accurcay = 0.92778
# [84, 3] running_loss = 0.04266 train accurcay = 0.92889
# [84, 6] running_loss = 0.04176 train accurcay = 0.92778
# [85, 3] running_loss = 0.04885 train accurcay = 0.91000
# [85, 6] running_loss = 0.04485 train accurcay = 0.92556
# [86, 3] running_loss = 0.04763 train accurcay = 0.93222
# [86, 6] running_loss = 0.03402 train accurcay = 0.93111
# [87, 3] running_loss = 0.05541 train accurcay = 0.93333
# [87, 6] running_loss = 0.02381 train accurcay = 0.93556
# [88, 3] running_loss = 0.04360 train accurcay = 0.88000
# [88, 6] running_loss = 0.10870 train accurcay = 0.90222
# [89, 3] running_loss = 0.03708 train accurcay = 0.92889
# [89, 6] running_loss = 0.04952 train accurcay = 0.90333
# [90, 3] running_loss = 0.03539 train accurcay = 0.92444
# [90, 6] running_loss = 0.05892 train accurcay = 0.91778
# [91, 3] running_loss = 0.05008 train accurcay = 0.90889
# [91, 6] running_loss = 0.04375 train accurcay = 0.89778
# [92, 3] running_loss = 0.05541 train accurcay = 0.93667
# [92, 6] running_loss = 0.03490 train accurcay = 0.92667
# [93, 3] running_loss = 0.04373 train accurcay = 0.92667
# [93, 6] running_loss = 0.03922 train accurcay = 0.93556
# [94, 3] running_loss = 0.03527 train accurcay = 0.93333
# [94, 6] running_loss = 0.04555 train accurcay = 0.93222
# [95, 3] running_loss = 0.05036 train accurcay = 0.92222
# [95, 6] running_loss = 0.04092 train accurcay = 0.91889
# [96, 3] running_loss = 0.04008 train accurcay = 0.93889
# [96, 6] running_loss = 0.03399 train accurcay = 0.92444
# [97, 3] running_loss = 0.03555 train accurcay = 0.89889
# [97, 6] running_loss = 0.06899 train accurcay = 0.90222
# [98, 3] running_loss = 0.03673 train accurcay = 0.93889
# [98, 6] running_loss = 0.03650 train accurcay = 0.93000
# [99, 3] running_loss = 0.03953 train accurcay = 0.93222
# [99, 6] running_loss = 0.02843 train accurcay = 0.94000
# [100, 3] running_loss = 0.03807 train accurcay = 0.93778
# [100, 6] running_loss = 0.03040 train accurcay = 0.93444
# training finish !

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

model.eval()
outputs_test = model(x_test)
_, prediction = torch.max(outputs_test, 1)

print('classification report: ')
print(classification_report(y_test,prediction,target_names=['Normal','Pneumonia','COVID-19']))
print('')

CM = confusion_matrix(y_test,prediction)
sns.set()
f,ax=plt.subplots()
print('confusion matrix: ')
sns.heatmap(CM,annot=True,ax=ax) 
ax.set_title('confusion matrix') 
ax.set_xlabel('predict') 
ax.set_ylabel('true')
# Out:
# classification report:
#               precision    recall  f1-score   support
#
#       Normal       0.29      0.28      0.29        25
#    Pneumonia       0.42      0.32      0.36        25
#     COVID-19       0.38      0.48      0.42        25
#
#     accuracy                           0.36        75
#    macro avg       0.36      0.36      0.36        75
# weighted avg       0.36      0.36      0.36        75
#
#
# confusion matrix:
# Text(30.5, 0.5, 'true')

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc
import itertools 

def get_roc_auc(trues, preds):
  labels = [0,1,2]
  nb_classes = len(labels)
  fpr = dict()
  tpr = dict()
  roc_auc = dict()

  #print(trues, preds)

  for i in range(nb_classes):
    fpr[i], tpr[i], _ = roc_curve(trues[:, i], preds[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

    # Compute micro-average ROC curve and ROC area
  fpr["micro"], tpr["micro"], _ = roc_curve(trues.ravel(), preds.ravel())
  roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

  # First aggregate all false positive rates
  all_fpr = np.unique(np.concatenate([fpr[i] for i in range(nb_classes)]))
  # Then interpolate all ROC curves at this points
  mean_tpr = np.zeros_like(all_fpr)

  for i in range(nb_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])
  # Finally average it and compute AUC
  mean_tpr /= nb_classes
  fpr["macro"] = all_fpr
  tpr["macro"] = mean_tpr
  roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])
  # Plot all ROC curves
  lw = 2
  plt.figure()
  plt.plot(fpr["micro"], tpr["micro"],label='micro-average ROC curve (area = {0:0.2f})'.format(roc_auc["micro"]),color='deeppink', linestyle=':', linewidth=4)
  plt.plot(fpr["macro"], tpr["macro"],label='macro-average ROC curve (area = {0:0.2f})'.format(roc_auc["macro"]),color='navy', linestyle=':', linewidth=4)

  colors = itertools.cycle(['aqua', 'darkorange', 'cornflowerblue'])
  label_name = ['Normal','Pneumonia','COVID-19']

  for i, color in zip(range(nb_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw, label='ROC curve of class {0} (area = {1:0.2f})'.format(label_name[i], roc_auc[i]))
  plt.plot([0, 1], [0, 1], 'k--', lw=lw)
  plt.xlim([0.0, 1.0])
  plt.ylim([0.0, 1.05])
  plt.xlabel('False Positive Rate')
  plt.ylabel('True Positive Rate')
  plt.title('ROC plot of GoogleNet')
  plt.legend(loc="lower right")
  plt.show()

test_trues = label_binarize(y_test, classes=[i for i in range(3)])
test_preds = label_binarize(prediction, classes=[i for i in range(3)])

get_roc_auc(test_trues, test_preds)

# %%
#from google.colab import drive
#drive.mount('/content/MyDrive/')
#torch.save(model, '/content/MyDrive/MyDrive/DATA5703/code/model/GoogleNet_model.pt')

#auth.authenticate_user()
#gauth = GoogleAuth()
#gauth.credentials = GoogleCredentials.get_application_default()
#drive = GoogleDrive(gauth)

#file_id = "1-6tJrNs3pG2eNvEJMVIsaBD_otymlwd7"
#downloaded = drive.CreateFile({'id': file_id})
#downloaded.GetContentFile('GoogleNet_model.pt')

#model = torch.load('GoogleNet_model.pt')
